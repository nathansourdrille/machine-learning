# %% [markdown]
# # Logistic regression

# %% [markdown]
# - régression linéaire: prédiction de la valeur.
# - régression logistique: prédiction d'une classe.

# %% [markdown]
# Contraitement à la régression linéaire, qui prédit une valeur continue, la régression logistique prédit la probabilité qu'un évènement se produise:
# P(y=1|X)= probabilité que label soit 1 sachant les features de X.

# %% [markdown]
# ## Synthetic data

# %% [markdown]
# On s'interesse à un problème de classification binaire avec y∈{0,1}.
# On doit générer des données synthétiques.
# Chaque classe est générée à partir d'une distribution gaussienne.
# - classe 0: x ~ N(μ0​,S0)
# - class 1: x ~ N(μ1​,S1​)

# %%
from utility import gen_data_twogaussians_2d
import numpy as np
import matplotlib.pyplot as plt

# classe 1
# 100 samples 
n1 = 100
# tous les points de (1) seront générées autour de (0,2)
mu1 = np.array([0,2])
S1 = 1.5*np.array([[1,0.1],[0.1,1]])
# classe 2
# 100 samples
n2 = 100
mu2 = np.array([-2,-2])
S2 = 3.5*np.array([[1,-0.25],[-0.25,0.5]])

# %%
# génère les données d'entraînement
# X_train: tableau; array(n1+n2,2)
# Y_train: vecteur; array(n1+n2,)
X_train, Y_train = gen_data_twogaussians_2d(mu1,S1,mu2,S2,n1,n2)

# %%
# affichage des données 
plt.scatter(X_train[Y_train == 1, 0], X_train[Y_train == 1, 1])
plt.scatter(X_train[Y_train == 2, 0], X_train[Y_train == 2, 1])
plt.show()

# %% [markdown]
# La régression logistique apprend une frontière de décision linéaire qui sépare les deux classes selon une formule.

# %%
from sklearn import linear_model
# penalty="none": pas dé régularisation => on fait confiance aux données
# solver="lbgfs": algortihme pour optimiser les coefficients
clf_reglog = linear_model.LogisticRegression(penalty=None,solver="lbfgs")
# le modèle calcule les meilleurs coefficients pour que la régression
# logistique sépare au mieux les deux classes
clf_reglog.fit(X_train, Y_train)
# Out:
# LogisticRegression(penalty=None)

# %%
from utility import plot_decision_regions_2d
plot_decision_regions_2d(X_train, Y_train, clf_reglog,
                        resolution=0.02,
                        title="Régression logistique")

# %% [markdown]
# Les données sont bien séparées en deux classes distinctes.

# %% [markdown]
# ## Spam classification

# %% [markdown]
# Pour continuer, le problème est le suivant: on reçoit trop de mails et on veut prédire ou les ranger dans la boite mail. On a un dataset de 4601 mails à disposition, avec 57 features.

# %% [markdown]
# - 48 caractéristiques, comprises entre 0 et 100, indiquant le pourcentage de mots d'un message correspondant à un mot donné sur une liste fixe. Cette liste contient des mots tels que « affaires », « gratuit », etc.
# - 6 caractéristiques, dans [0, 100], indiquant le pourcentage de caractères du courriel correspondant à un caractère donné.
# parmi les caractères suivants : "(", "[", "!", "$", "#"
# - Les caractéristiques 55 à 57 représentent respectivement la longueur moyenne, la longueur la plus longue et la somme des
# longueurs de séquences ininterrompues de lettres majuscules.

# %%
dataspam = np.loadtxt("spambase/spambase.data", delimiter=",")
features_name = np.genfromtxt("spambase/spambase_variables.csv", 
                             delimiter=",", dtype="str")
features_name = features_name[:,0]

# %%
X = dataspam[:,0:57]
Y = dataspam[:,-1]
print(f"X contient {X.shape[0]} samples et {X.shape[1]} features")
# Out:
# X contient 4601 samples et 57 features

# %% [markdown]
# X: toutes les données.
# Y: labels des données: indique si oui ou non le mail est un spam.

# %%
features_name_plot = features_name[0:55]
plt.figure(figsize=(10,10))
plt.boxplot(X[:,0:54])
plt.xticks(ticks=range(0, 55), labels=[f"F{i}" for i in features_name_plot], rotation=90)
plt.title("Boîtes à moustache des features 1 à 54");

# %% [markdown]
# Boxplots peu intéressants.

# %%
features_name_plot = features_name[54:57]
plt.figure(figsize=(10,10))
plt.boxplot(X[:,54:57])
plt.xticks(ticks=range(1, 4), labels=[f"F{i}" for i in features_name_plot], rotation=90)
plt.title("Boites à moustaches des variables 55 à 57")
plt.show()
n= X[:,56].size

# %% [markdown]
# On remarque une grande différence d'échelle entre les features.

# %%
count_0 = [x for x in Y if x == 0]
print(len(count_0),"mails non spams")

count_1 = [x for x in Y if x == 1]
print(len(count_1),"mails spams")
# Out:
# 2788 mails non spams
# 1813 mails spams

# %% [markdown]
# La régression logistique convertit une combinaison linéaire des features en probabilité, puis décide de la classe selon un seuil.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(
    X,Y, test_size=1/3, train_size=2/3, shuffle=True, stratify=Y)

# normalise les donénes
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

clf_spam = linear_model.LogisticRegression(penalty=None, solver="lbfgs")
clf_spam.fit(X_train_scaled,Y_train)
# Out:
# LogisticRegression(penalty=None)

# %%
from sklearn.metrics import accuracy_score
acc_train = accuracy_score(Y_train, Y_pred_train)
print(f"Accuracy on training data = {np.round(100*acc_train)}%")
# Out:
# Accuracy on training data = 93.0%

# %%
acc_train = accuracy_score(Y_test, Y_pred_test)
print(f"Accuracy on test data = {np.round(100*acc_train)}%")
# Out:
# Accuracy on test data = 92.0%

# %% [markdown]
# Le modèle apprend bien sur les données d'entraînement et performe sur des données nouvelles donc le modèle généralise bien. La différence de 1% seulement est excellente.
# En résumé, le modèle de régression logistique a appris correctement les données d'entraînement et généralise très bien sur les données de test.

# %%
# index contient les indices des features triés du - au + important
index = np.argsort(np.abs(np.squeeze(clf_spam.coef_)))
# on inverse l'odre pour avec les features du + au - important
index = index[::-1]
print("{:<38s}{:<18s}".format("Variables", "Coefficient"))
for var, coef in zip(features_name[index], clf_spam.coef_[0,index]):
    print("{:<28s}{:>16.2f}".format(var, coef))
# Out:
# Variables                             Coefficient
# word_freq_george                      -15.68
# word_freq_cs                           -6.26
# word_freq_3d                            3.47
# word_freq_hp                           -3.06
# word_freq_85                           -2.07
# word_freq_telnet                       -1.85
# word_freq_edu                          -1.46
# capital_run_length_longest              1.44
# word_freq_meeting                      -1.43
# word_freq_000                           1.31
# word_freq_lab                          -1.18
# char_freq_$                             1.08
# word_freq_hpl                          -1.06
# word_freq_remove                        1.00
# word_freq_conference                   -1.00
# word_freq_project                      -0.91
# word_freq_free                          0.84
# char_freq_sharp                         0.78
# word_freq_re                           -0.73
# word_freq_credit                        0.65
# capital_run_length_average              0.51
# word_freq_technology                    0.51
# char_freq_!                             0.44
# word_freq_pm                           -0.44
# word_freq_business                      0.39
# char_freq_;                            -0.38
# word_freq_font                          0.34
# word_freq_original                     -0.33
# word_freq_our                           0.32
# word_freq_data                         -0.31
# capital_run_length_total                0.30
# word_freq_money                         0.28
# word_freq_your                          0.27
# word_freq_internet                      0.24
# word_freq_addresses                     0.24
# word_freq_650                           0.22
# word_freq_over                          0.21
# word_freq_address                      -0.21
# word_freq_labs                         -0.19
# word_freq_order                         0.16
# char_freq_[                            -0.15
# word_freq_receive                      -0.11
# word_freq_parts                        -0.11
# word_freq_you                           0.10
# word_freq_table                        -0.10
# word_freq_857                           0.09
# word_freq_will                         -0.08
# word_freq_direct                       -0.08
# word_freq_mail                          0.08
# word_freq_email                         0.07
# word_freq_make                         -0.06
# word_freq_people                        0.05
# word_freq_all                           0.04
# word_freq_415                          -0.02
# word_freq_1999                          0.02
# word_freq_report                        0.00
# char_freq_(                            -0.00

# %% [markdown]
# Les 10 features les plus importantes pour dire qu'un mail n'est pas un spam sont:
# - word_freq_george;                      -15.68
# - word_freq_cs;                           -6.26
# - word_freq_3d;                            3.47
# - word_freq_hp;                           -3.06
# - word_freq_85;                           -2.07
# - word_freq_telnet;                       -1.85
# - word_freq_edu;                          -1.46
# - capital_run_length_longest;              1.44
# - word_freq_meeting;                      -1.43
# - word_freq_000;                           1.31

# %% [markdown]
# Entre l'apprentissge avec données normalisées et non-normalisées, l'ordre des features changent dans la liste.
#
# ---

# %%
# epsilon garantit que toutes les valeurs soient strictement positives
epsilon = 0.01
X_train_n = np.log(X_train + epsilon)
X_test_n = np.log(X_test + epsilon)

# %%
clf_spam = linear_model.LogisticRegression(penalty=None, solver="lbfgs")
clf_spam.fit(X_train_n,Y_train)
# Out:
# /home/nathan/.local/share/virtualenvs/image-processing-ZZ_c8egw/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(penalty=None)

# %%
Y_pred_train = clf_spam.predict(X_train_n)
Y_pred_test = clf_spam.predict(X_test_n)

# %%
acc_train = accuracy_score(Y_train, Y_pred_train)
print(f"Accuracy on training data = {np.round(100*acc_train)}%")
# Out:
# Accuracy on training data = 95.0%

# %%
acc_train = accuracy_score(Y_test, Y_pred_test)
print(f"Accuracy on test data = {np.round(100*acc_train)}%")
# Out:
# Accuracy on test data = 95.0%

# %% [markdown]
# Cette fois, on obtient dans les deux cas un score de 95%, ce qui est plus haut que le score obtenu en ayant normalisé les données. L'utilisation du logarithme permet de resserrer les grandes valeurs et réduire l'impact des outliers, certaines relations deviennent plus linéaires ce qui aide la régression logistique à mieux apprendre.

# %% [markdown]
# | Aspect                     | Normalisation / Standardisation                       | Logarithme                                   |
# |-----------------------------|-------------------------------------------------------|---------------------------------------------|
# | Objectif                    | Mettre toutes les features sur la même échelle      | Réduire l’effet des valeurs extrêmes, linéariser des relations |
# | Transformation              | Linéaire                                              | Non-linéaire                                 |
# | Impact sur la distribution  | Moyenne et écart-type modifiés, shape conservé       | Distribution modifiée, compression des grandes valeurs |
# | Sensible aux outliers ?     | Oui (les outliers restent)                            | Non (grandes valeurs compressées)           |
# | Quand utile                 | Pour optimiser convergence et balance des features  | Pour features skewed ou relations exponentielles |

# %%
# histogramme de chaque feature
plt.figure(figsize=(18, 18))
vartype = "log" 
for i in range(X.shape[1]):
    plt.subplot(8,8,i+1)
    if vartype=="log":
        plt.hist(np.log(X[:,i]+epsilon))
    else:
        plt.hist(X[:,i])
    plt.xticks(fontsize=5); plt.yticks(fontsize=6)

# %% [markdown]
# ## Extension to multi-class classification

# %%
# training set
mnist_train = np.loadtxt("./Mnist/mnist-app.csv", delimiter=",")
Y_train = mnist_train[:,-1]
X_train = mnist_train[:, 0:784]
# test set
mnist_test = np.loadtxt("./Mnist/mnist-test.csv", delimiter=",")
Y_test = mnist_test[:,-1]
X_test = mnist_test[:, 0:784]

# %%
# affichage des données 
fig, ax_array = plt.subplots(6, 6)
axes = ax_array.flatten()
for i, ax in enumerate(axes):
    ax.imshow(X_train[i].reshape(28, 28), cmap="gray_r")
plt.setp(axes, xticks=[], yticks=[], frame_on=False)
plt.tight_layout(h_pad=0.5, w_pad=0.01)

# %%
from sklearn import linear_model
clf = linear_model.LogisticRegression(tol=1e-2, 
                                      solver="lbfgs", C=1, max_iter=2500)

# %%
clf.fit(X_train, Y_train)
Y_pred_train = clf_spam.predict(X_train)
Y_pred_test = clf_spam.predict(X_test)

# %%
acc_train = accuracy_score(Y_train, Y_pred_train)
print(f"Accuracy on training data = {np.round(100*acc_train)}%")

# %%
acc_train = accuracy_score(Y_test, Y_pred_test)
print(f"Accuracy on test data = {np.round(100*acc_train)}%")

# %% [markdown]
# Les scores sont bons.
